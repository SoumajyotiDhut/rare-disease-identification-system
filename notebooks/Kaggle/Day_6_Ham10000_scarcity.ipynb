# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/hmnist_8_8_RGB.csv
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/hmnist_28_28_RGB.csv
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/hmnist_8_8_L.csv
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/hmnist_28_28_L.csv
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_metadata.csv
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028933.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028394.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027799.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028100.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027960.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028872.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026412.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024872.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026232.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027031.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026692.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025729.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028582.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024754.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027742.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025408.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026474.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027164.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027228.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028059.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028588.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029299.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027221.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024912.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028259.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025844.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028090.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025454.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028842.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026980.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026662.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025037.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025876.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024901.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025611.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027201.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025536.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027941.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026620.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026352.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026239.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025595.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026534.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027384.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026476.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025575.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024862.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025553.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027136.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025702.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026957.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024467.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024725.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026203.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028507.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028942.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026682.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028456.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025159.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024466.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024542.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027646.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026259.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028544.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027908.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028829.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025922.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024841.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029291.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026238.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028075.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026317.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025720.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028520.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025087.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028834.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024710.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026797.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025051.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025399.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027066.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029300.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024511.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027468.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027100.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025272.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029056.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027834.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028005.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028183.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028607.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024427.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027851.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028403.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026669.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027426.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025427.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024433.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028347.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025677.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024713.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026127.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026374.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029034.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027559.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027982.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028201.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027580.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024663.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024370.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028232.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025706.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025599.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027349.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027331.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024850.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026484.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029006.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027731.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027611.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026193.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025698.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028063.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028642.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025111.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029114.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027477.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029208.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027034.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029086.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024650.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026371.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026825.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025224.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028823.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029128.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026798.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026111.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024497.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027390.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029064.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026332.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029139.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028866.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025894.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028443.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025675.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029140.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027640.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026380.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024554.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026915.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025694.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026595.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027620.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028656.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027184.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028967.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025799.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027662.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028557.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026114.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027087.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024644.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028300.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029087.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026526.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025010.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027042.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029123.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028214.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027107.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026205.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029189.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027099.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024406.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025230.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027267.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028710.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026996.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029049.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027005.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026943.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024688.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027846.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028649.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026053.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026421.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024639.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025300.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025136.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027627.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028830.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026543.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028927.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026830.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027534.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024329.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029111.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027710.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025602.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028204.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028137.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027536.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025810.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027040.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027740.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024753.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024981.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027023.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026694.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024778.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028024.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029221.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025733.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026956.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027163.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024712.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027976.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027604.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026166.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026655.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028808.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028492.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024853.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028136.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028186.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028637.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028657.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026745.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028025.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028246.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028428.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024817.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025446.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026126.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027383.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026149.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024478.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027733.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028503.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025187.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025954.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028679.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029190.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028737.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026309.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027572.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028026.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028526.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024801.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029072.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027054.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028678.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028982.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028530.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028402.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025198.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026346.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027983.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026230.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027481.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028924.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026640.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026189.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027216.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026953.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027672.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028567.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026796.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024762.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026530.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028337.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029297.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027634.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027801.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027647.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024530.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029142.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025626.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028890.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028335.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027785.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025295.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026998.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024668.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026434.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027106.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026083.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024623.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024835.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025183.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025362.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028308.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024799.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026613.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029169.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028294.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025106.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028871.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025633.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028985.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025908.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028676.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025997.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027748.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028500.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027806.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027233.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027149.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026766.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027676.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027020.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025480.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025179.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028600.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026834.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027928.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024910.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027865.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027614.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026772.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027133.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026303.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026437.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028543.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029057.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024671.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029143.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027371.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025487.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024435.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027868.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025428.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026910.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025325.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025082.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028694.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025322.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025948.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026936.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027460.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027861.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029173.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028194.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026094.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025927.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029266.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024371.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024449.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025342.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024792.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024541.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024744.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027085.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024398.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029102.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028433.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026395.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024736.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024705.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026931.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027252.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024547.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027474.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026900.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029156.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026221.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027396.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027288.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024451.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028330.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024514.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025424.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025242.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027035.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028189.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028591.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028173.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028154.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028438.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025336.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026312.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025559.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029092.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028915.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026125.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027142.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025965.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027214.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029118.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028521.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025582.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026326.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025458.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027258.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028240.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025135.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025700.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028565.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024959.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029152.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027172.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025002.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026860.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029022.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027080.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025529.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026092.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025617.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025240.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025913.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027089.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028857.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028305.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027109.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028785.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025772.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027755.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029212.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027382.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028289.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024721.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026160.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025707.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025149.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028217.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028111.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028132.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027368.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027589.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024819.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025112.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024430.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028836.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024845.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027405.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027649.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028420.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028226.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025171.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025279.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027875.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027229.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028480.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026984.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028231.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027560.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027381.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026415.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027171.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025000.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026967.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027829.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026003.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024964.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026444.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025071.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026048.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024884.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026156.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028812.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027458.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028497.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025979.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027218.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025737.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026274.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025124.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028536.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025413.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026430.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028749.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028498.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025355.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025131.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028968.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028094.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029248.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0026954.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025537.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027488.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027880.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025516.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025441.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024352.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0025479.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0024896.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0027459.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0028334.jpg
# ...
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031204.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033676.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031820.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029933.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034014.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032459.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032333.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031063.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032508.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032272.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031079.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031093.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029475.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029596.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033426.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032633.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033776.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033854.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031919.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031972.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032283.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034220.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029856.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029943.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029602.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031828.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032395.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033435.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032189.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031066.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033339.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032349.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029511.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033014.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031654.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032870.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032273.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031743.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031905.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031814.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031821.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031688.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033548.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034162.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030947.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029505.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030341.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032356.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029949.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030635.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033404.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030826.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032716.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031500.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032489.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034146.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030348.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029489.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034168.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031274.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032423.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030412.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030657.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033656.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031219.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031086.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030185.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030579.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032645.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033411.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031539.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030977.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033569.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031588.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029897.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030138.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033297.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032198.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030082.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029579.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033851.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033767.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033638.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031421.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031233.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034109.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034290.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033650.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033385.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034119.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032617.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031870.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031226.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032550.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030246.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032131.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032652.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033869.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030605.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033575.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032203.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033740.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033796.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033938.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033388.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033247.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031922.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032853.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030736.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031225.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034001.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033619.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031623.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034026.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031491.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032252.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034189.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031792.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034010.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031255.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031832.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030545.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030994.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031911.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032993.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032613.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032376.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033485.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029948.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033802.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032466.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029393.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029423.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032058.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032155.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031859.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034076.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033220.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030845.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033255.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033703.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0034090.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032771.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030265.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029330.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032485.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033781.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031869.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030474.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030459.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033906.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032422.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031726.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0031279.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033165.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032972.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030091.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030780.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030674.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0029733.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0033470.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0032153.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030216.jpg
# /kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000/ham10000_images_part_2/ISIC_0030344.jpg

# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import json
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.metrics import accuracy_score, f1_score

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"✓ Device: {torch.cuda.get_device_name(0)}")

# Verify HAM10000 is attached
HAM_PATH = "/kaggle/input/datasets/kmader/skin-cancer-mnist-ham10000"

print(f"\nHAM10000 contents:")
for item in os.listdir(HAM_PATH):
    full = os.path.join(HAM_PATH, item)
    if os.path.isdir(full):
        count = len(os.listdir(full))
        print(f"  [DIR]  {item}/  ({count} files)")
    else:
        size = os.path.getsize(full) / (1024*1024)
        print(f"  [FILE] {item}  ({size:.1f} MB)")
# Out:
# ✓ Device: Tesla T4
#
# HAM10000 contents:
#   [FILE] hmnist_8_8_RGB.csv  (7.2 MB)
#   [FILE] hmnist_28_28_RGB.csv  (87.6 MB)
#   [DIR]  HAM10000_images_part_1/  (5000 files)
#   [DIR]  ham10000_images_part_1/  (5000 files)
#   [FILE] hmnist_8_8_L.csv  (2.4 MB)
#   [DIR]  HAM10000_images_part_2/  (5015 files)
#   [DIR]  ham10000_images_part_2/  (5015 files)
#   [FILE] hmnist_28_28_L.csv  (29.4 MB)
#   [FILE] HAM10000_metadata.csv  (0.5 MB)

# %%
# Load metadata
meta = pd.read_csv(f"{HAM_PATH}/HAM10000_metadata.csv")

print("=" * 50)
print("HAM10000 OVERVIEW")
print("=" * 50)
print(f"Total samples    : {len(meta)}")
print(f"Unique diseases  : {meta['dx'].nunique()}")
print(f"\nClass distribution:")
print(meta['dx'].value_counts())

# Map disease codes to full names
dx_map = {
    'nv'  : 'Melanocytic nevi',
    'mel' : 'Melanoma',
    'bkl' : 'Benign keratosis',
    'bcc' : 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df'  : 'Dermatofibroma'
}
meta['dx_full'] = meta['dx'].map(dx_map)

# Plot class distribution
plt.figure(figsize=(10, 4))
counts = meta['dx'].value_counts()
plt.bar(counts.index, counts.values, color='#378ADD')
plt.title('HAM10000 — Class Distribution')
plt.xlabel('Disease')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('/kaggle/working/ham10000_distribution.png',
            dpi=150, bbox_inches='tight')
plt.show()
print("✓ Distribution plot saved")
# Out:
# ==================================================
# HAM10000 OVERVIEW
# ==================================================
# Total samples    : 10015
# Unique diseases  : 7
#
# Class distribution:
# dx
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: count, dtype: int64
# ✓ Distribution plot saved

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# Find all images
img_dir1 = f"{HAM_PATH}/HAM10000_images_part_1"
img_dir2 = f"{HAM_PATH}/HAM10000_images_part_2"

# Build full path for each image
def find_image_path(image_id):
    for d in [img_dir1, img_dir2]:
        path = os.path.join(d, f"{image_id}.jpg")
        if os.path.exists(path):
            return path
    return None

print("Building image paths...")
meta['image_path'] = meta['image_id'].apply(find_image_path)
missing = meta['image_path'].isna().sum()
print(f"✓ Paths built")
print(f"  Found   : {meta['image_path'].notna().sum()}")
print(f"  Missing : {missing}")

# Encode labels
le = LabelEncoder()
meta['label'] = le.fit_transform(meta['dx'])
NUM_CLASSES = len(le.classes_)
print(f"  Classes : {NUM_CLASSES}")
print(f"  Labels  : {list(le.classes_)}")

# ── 5-10% CLASS-WISE SAMPLER ──────────────────────────────────
def sample_per_class(df, frac=0.10, min_samples=3):
    sampled = []
    for cls in df['dx'].unique():
        cls_df = df[df['dx'] == cls]
        n      = max(min_samples, int(len(cls_df) * frac))
        n      = min(n, len(cls_df))
        sampled.append(cls_df.sample(n=n, random_state=42))
    return pd.concat(sampled).reset_index(drop=True)

# Drop missing paths
meta_clean = meta.dropna(
    subset=['image_path']).reset_index(drop=True)

# Create splits
exp1_train = sample_per_class(meta_clean, frac=0.10)
remaining  = meta_clean[
    ~meta_clean['image_id'].isin(exp1_train['image_id'])
].reset_index(drop=True)

# 80/20 split for full dataset
full_train, full_test = train_test_split(
    meta_clean, test_size=0.2,
    random_state=42, stratify=meta_clean['dx']
)
full_train = full_train.reset_index(drop=True)
full_test  = full_test.reset_index(drop=True)

# Use remaining as test for exp1
exp1_test = remaining.copy()

print(f"\n✓ Splits ready")
print(f"  Exp1 train (5-10%) : {len(exp1_train)} samples")
print(f"  Exp1 test          : {len(exp1_test)} samples")
print(f"  Full train         : {len(full_train)} samples")
print(f"  Full test          : {len(full_test)} samples")
print(f"\nExp1 class distribution:")
print(exp1_train['dx'].value_counts())
# Out:
# Building image paths...
# ✓ Paths built
#   Found   : 10015
#   Missing : 0
#   Classes : 7
#   Labels  : ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
#
# ✓ Splits ready
#   Exp1 train (5-10%) : 998 samples
#   Exp1 test          : 9017 samples
#   Full train         : 8012 samples
#   Full test          : 2003 samples
#
# Exp1 class distribution:
# dx
# nv       670
# mel      111
# bkl      109
# bcc       51
# akiec     32
# vasc      14
# df        11
# Name: count, dtype: int64

# %%
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from PIL import Image

class HAMDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df        = df.reset_index(drop=True)
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        try:
            img = Image.open(row['image_path']).convert('RGB')
            if self.transform:
                img = self.transform(img)
        except:
            img = torch.zeros(3, 224, 224)
        return {
            'image': img,
            'label': torch.tensor(row['label'], dtype=torch.long)
        }

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(
        brightness=0.3, contrast=0.3, saturation=0.3),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406],
                         [0.229, 0.224, 0.225])
])

# Exp1 datasets (5-10% scarcity)
exp1_train_ds = HAMDataset(exp1_train, train_transform)
exp1_test_ds  = HAMDataset(exp1_test,  test_transform)

exp1_train_loader = DataLoader(exp1_train_ds, batch_size=32,
                                shuffle=True,  num_workers=4)
exp1_test_loader  = DataLoader(exp1_test_ds,  batch_size=32,
                                shuffle=False, num_workers=4)

print(f"✓ Exp1 DataLoaders ready")
print(f"  Train samples : {len(exp1_train_ds)}")
print(f"  Test samples  : {len(exp1_test_ds)}")
print(f"  Train batches : {len(exp1_train_loader)}")
# Out:
# ✓ Exp1 DataLoaders ready
#   Train samples : 998
#   Test samples  : 9017
#   Train batches : 32

# %%
import torchvision.models as models
from torch.optim import AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR

class ResNet50Classifier(nn.Module):
    def __init__(self, num_classes, dropout=0.4):
        super().__init__()
        backbone = models.resnet50(
            weights=models.ResNet50_Weights.IMAGENET1K_V1)
        for layer in list(backbone.children())[:-3]:
            for param in layer.parameters():
                param.requires_grad = False
        self.features   = nn.Sequential(
            *list(backbone.children())[:-1])
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Dropout(dropout),
            nn.Linear(2048, 512),
            nn.ReLU(),
            nn.BatchNorm1d(512),
            nn.Dropout(dropout),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        return self.classifier(self.features(x))

EPOCHS   = 15
model    = ResNet50Classifier(NUM_CLASSES).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = AdamW(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=1e-4, weight_decay=0.01
)
scheduler = CosineAnnealingLR(
    optimizer, T_max=EPOCHS, eta_min=1e-6)

train_losses = []
train_accs   = []

print(f"Training on 5-10% HAM10000 — {EPOCHS} epochs")
print(f"  Train samples : {len(exp1_train_ds)}")
print(f"  Classes       : {NUM_CLASSES}")
print("-" * 55)

for epoch in range(EPOCHS):
    model.train()
    total_loss, correct, total = 0, 0, 0

    for batch in exp1_train_loader:
        images = batch['image'].to(device)
        labels = batch['label'].to(device)

        optimizer.zero_grad()
        logits = model(images)
        loss   = criterion(logits, labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(
            model.parameters(), 1.0)
        optimizer.step()

        total_loss += loss.item()
        correct    += (logits.argmax(1) == labels).sum().item()
        total      += labels.size(0)

    scheduler.step()
    avg_loss = total_loss / len(exp1_train_loader)
    acc      = correct / total * 100
    train_losses.append(avg_loss)
    train_accs.append(acc)
    print(f"Epoch {epoch+1:02d}/{EPOCHS} | "
          f"Loss: {avg_loss:.4f} | "
          f"Train Acc: {acc:.2f}%")

print("-" * 55)
print("✓ Training complete")
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 246MB/s]
# Training on 5-10% HAM10000 — 15 epochs
#   Train samples : 998
#   Classes       : 7
# -------------------------------------------------------
# Epoch 01/15 | Loss: 1.8541 | Train Acc: 34.87%
# Epoch 02/15 | Loss: 1.4011 | Train Acc: 59.32%
# Epoch 03/15 | Loss: 1.0957 | Train Acc: 72.55%
# Epoch 04/15 | Loss: 0.9491 | Train Acc: 74.55%
# Epoch 05/15 | Loss: 0.7640 | Train Acc: 77.76%
# Epoch 06/15 | Loss: 0.6431 | Train Acc: 81.96%
# Epoch 07/15 | Loss: 0.6184 | Train Acc: 83.77%
# Epoch 08/15 | Loss: 0.4549 | Train Acc: 87.68%
# Epoch 09/15 | Loss: 0.3922 | Train Acc: 89.38%
# Epoch 10/15 | Loss: 0.3217 | Train Acc: 90.98%
# Epoch 11/15 | Loss: 0.3154 | Train Acc: 91.68%
# Epoch 12/15 | Loss: 0.2099 | Train Acc: 95.19%
# Epoch 13/15 | Loss: 0.3798 | Train Acc: 93.29%
# Epoch 14/15 | Loss: 0.2130 | Train Acc: 93.99%
# Epoch 15/15 | Loss: 0.2482 | Train Acc: 92.99%
# -------------------------------------------------------
# ✓ Training complete

# %%
def evaluate_topk(model, loader, device, k=5):
    model.eval()
    all_preds, all_labels = [], []
    top5_correct, total   = 0, 0

    with torch.no_grad():
        for batch in loader:
            images = batch['image'].to(device)
            labels = batch['label'].to(device)
            logits = model(images)

            preds  = logits.argmax(dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            # Top-K (use min of k and num_classes)
            k_actual = min(k, logits.size(1))
            topk = logits.topk(k_actual, dim=1).indices
            for i, lbl in enumerate(labels):
                if lbl in topk[i]:
                    top5_correct += 1
            total += labels.size(0)

    return {
        "accuracy"     : round(accuracy_score(
                            all_labels, all_preds)*100, 2),
        "f1_macro"     : round(f1_score(
                            all_labels, all_preds,
                            average='macro',
                            zero_division=0)*100, 2),
        "f1_weighted"  : round(f1_score(
                            all_labels, all_preds,
                            average='weighted',
                            zero_division=0)*100, 2),
        "top5_accuracy": round(top5_correct/total*100, 2),
        "total_samples": total
    }

# Evaluate Exp1
print("Evaluating Exp1 (5-10% scarcity)...")
exp1_metrics = evaluate_topk(model, exp1_test_loader, device)

print("\n" + "=" * 55)
print("EXP 1 — HAM10000 BASELINE (5-10% scarcity)")
print("=" * 55)
print(f"  Accuracy     : {exp1_metrics['accuracy']}%")
print(f"  F1 Macro     : {exp1_metrics['f1_macro']}%")
print(f"  F1 Weighted  : {exp1_metrics['f1_weighted']}%")
print(f"  Top-5 Acc    : {exp1_metrics['top5_accuracy']}%")
print(f"  Test samples : {exp1_metrics['total_samples']}")

# Save exp1 model
torch.save({
    'model_state_dict': model.state_dict(),
    'le_classes'      : list(le.classes_),
    'metrics'         : exp1_metrics
}, '/kaggle/working/ham_exp1_baseline.pt')
print(f"\n✓ Exp1 model saved")
# Out:
# Evaluating Exp1 (5-10% scarcity)...
#
# =======================================================
# EXP 1 — HAM10000 BASELINE (5-10% scarcity)
# =======================================================
#   Accuracy     : 77.3%
#   F1 Macro     : 55.53%
#   F1 Weighted  : 77.18%
#   Top-5 Acc    : 94.27%
#   Test samples : 9017
#
# ✓ Exp1 model saved

# %%
# Full dataset DataLoaders
full_train_ds = HAMDataset(full_train, train_transform)
full_test_ds  = HAMDataset(full_test,  test_transform)

full_train_loader = DataLoader(full_train_ds, batch_size=32,
                                shuffle=True,  num_workers=4)
full_test_loader  = DataLoader(full_test_ds,  batch_size=32,
                                shuffle=False, num_workers=4)

# New model for full training
model_full = ResNet50Classifier(NUM_CLASSES).to(device)
optimizer2 = AdamW(
    filter(lambda p: p.requires_grad, model_full.parameters()),
    lr=1e-4, weight_decay=0.01
)
scheduler2 = CosineAnnealingLR(
    optimizer2, T_max=EPOCHS, eta_min=1e-6)

full_losses = []
full_accs   = []

print(f"Training on FULL HAM10000 — {EPOCHS} epochs")
print(f"  Train samples : {len(full_train_ds)}")
print("-" * 55)

for epoch in range(EPOCHS):
    model_full.train()
    total_loss, correct, total = 0, 0, 0

    for batch in full_train_loader:
        images = batch['image'].to(device)
        labels = batch['label'].to(device)

        optimizer2.zero_grad()
        logits = model_full(images)
        loss   = criterion(logits, labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(
            model_full.parameters(), 1.0)
        optimizer2.step()

        total_loss += loss.item()
        correct    += (logits.argmax(1) == labels).sum().item()
        total      += labels.size(0)

    scheduler2.step()
    avg_loss = total_loss / len(full_train_loader)
    acc      = correct / total * 100
    full_losses.append(avg_loss)
    full_accs.append(acc)
    print(f"Epoch {epoch+1:02d}/{EPOCHS} | "
          f"Loss: {avg_loss:.4f} | "
          f"Train Acc: {acc:.2f}%")

print("-" * 55)
print("✓ Full training complete")

# Evaluate full model
print("\nEvaluating full dataset model...")
full_metrics = evaluate_topk(
    model_full, full_test_loader, device)

print("\n" + "=" * 55)
print("EXP 3 — HAM10000 UPPER BOUND (Full Dataset)")
print("=" * 55)
print(f"  Accuracy     : {full_metrics['accuracy']}%")
print(f"  F1 Macro     : {full_metrics['f1_macro']}%")
print(f"  F1 Weighted  : {full_metrics['f1_weighted']}%")
print(f"  Top-5 Acc    : {full_metrics['top5_accuracy']}%")
print(f"  Test samples : {full_metrics['total_samples']}")

torch.save({
    'model_state_dict': model_full.state_dict(),
    'le_classes'      : list(le.classes_),
    'metrics'         : full_metrics
}, '/kaggle/working/ham_exp3_full.pt')
print(f"\n✓ Full model saved")
# Out:
# Training on FULL HAM10000 — 15 epochs
#   Train samples : 8012
# -------------------------------------------------------
# Epoch 01/15 | Loss: 1.2627 | Train Acc: 65.15%
# Epoch 02/15 | Loss: 0.8459 | Train Acc: 76.21%
# Epoch 03/15 | Loss: 0.6826 | Train Acc: 79.41%
# Epoch 04/15 | Loss: 0.5653 | Train Acc: 81.93%
# Epoch 05/15 | Loss: 0.5168 | Train Acc: 83.18%
# Epoch 06/15 | Loss: 0.4672 | Train Acc: 84.74%
# Epoch 07/15 | Loss: 0.3841 | Train Acc: 87.12%
# Epoch 08/15 | Loss: 0.3518 | Train Acc: 88.78%
# Epoch 09/15 | Loss: 0.2850 | Train Acc: 90.21%
# Epoch 10/15 | Loss: 0.2563 | Train Acc: 91.48%
# Epoch 11/15 | Loss: 0.2082 | Train Acc: 92.79%
# Epoch 12/15 | Loss: 0.1912 | Train Acc: 93.78%
# Epoch 13/15 | Loss: 0.1597 | Train Acc: 94.57%
# Epoch 14/15 | Loss: 0.1700 | Train Acc: 94.76%
# Epoch 15/15 | Loss: 0.1399 | Train Acc: 94.95%
# -------------------------------------------------------
# ✓ Full training complete
#
# Evaluating full dataset model...
#
# =======================================================
# EXP 3 — HAM10000 UPPER BOUND (Full Dataset)
# =======================================================
#   Accuracy     : 87.72%
#   F1 Macro     : 79.25%
#   F1 Weighted  : 87.56%
#   Top-5 Acc    : 99.05%
#   Test samples : 2003
#
# ✓ Full model saved

# %%
# Plot comparison
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].plot(train_losses, color='#D85A30',
             linewidth=2, marker='o', markersize=3,
             label='Exp1 (5-10%)')
axes[0].plot(full_losses, color='#1D9E75',
             linewidth=2, marker='o', markersize=3,
             label='Full dataset')
axes[0].set_title('HAM10000 — Training Loss')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

axes[1].plot(train_accs, color='#D85A30',
             linewidth=2, marker='o', markersize=3,
             label='Exp1 (5-10%)')
axes[1].plot(full_accs, color='#1D9E75',
             linewidth=2, marker='o', markersize=3,
             label='Full dataset')
axes[1].set_title('HAM10000 — Training Accuracy')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy (%)')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.suptitle('HAM10000 — Scarcity vs Full Dataset',
             fontsize=13, fontweight='bold')
plt.tight_layout()
plt.savefig('/kaggle/working/day6_ham10000_comparison.png',
            dpi=150, bbox_inches='tight')
plt.show()

# Save summary
summary = {
    "day"         : 6,
    "dataset"     : "HAM10000",
    "exp1_metrics": exp1_metrics,
    "full_metrics": full_metrics,
    "scarcity_gap": {
        "accuracy_gap": round(
            full_metrics['accuracy'] -
            exp1_metrics['accuracy'], 2),
        "top5_gap"    : round(
            full_metrics['top5_accuracy'] -
            exp1_metrics['top5_accuracy'], 2)
    },
    "status": "Day 6 complete"
}

with open('/kaggle/working/day6_summary.json', 'w') as f:
    json.dump(summary, f, indent=2)

print("\n" + "=" * 55)
print("DAY 6 COMPLETE ✓")
print("=" * 55)
print(f"  HAM Exp1 — Accuracy : {exp1_metrics['accuracy']}%")
print(f"  HAM Exp1 — Top-5    : {exp1_metrics['top5_accuracy']}%")
print(f"  HAM Full — Accuracy : {full_metrics['accuracy']}%")
print(f"  HAM Full — Top-5    : {full_metrics['top5_accuracy']}%")
print(f"\n  Scarcity Gap:")
print(f"    Accuracy : {summary['scarcity_gap']['accuracy_gap']}%")
print(f"    Top-5    : {summary['scarcity_gap']['top5_gap']}%")
print(f"\n  Next → Day 7: ZebraMap baseline (Exp 4)")
# Out:
# =======================================================
# DAY 6 COMPLETE ✓
# =======================================================
#   HAM Exp1 — Accuracy : 77.3%
#   HAM Exp1 — Top-5    : 94.27%
#   HAM Full — Accuracy : 87.72%
#   HAM Full — Top-5    : 99.05%
#
#   Scarcity Gap:
#     Accuracy : 10.42%
#     Top-5    : 4.78%
#
#   Next → Day 7: ZebraMap baseline (Exp 4)
